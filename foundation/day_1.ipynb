# %% [markdown]
# * Task 1 — Warmup (15 mins)
#
# Write a program that asks the user their name and age, then prints

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))
print(f"Hello {name}! you are {age} years old.\nIn 10 years you will be {age+10}")
# Out:
# Hello sushant! you are 20 years old.
# In 10 years you will be 30

# %% [markdown]
# * Task 2 — Core Exercise (30 mins)
#
# Write a program called student_profile.py

# %%
name = input("Enter your name: ")
branch = input("Enter your branch: ")
year = int(input("Enter your curent year: "))
print(f"Hello {name}! you are in {branch} branch.\nyear:{year}\nyour subjects are:")
subjects = ["Maths", "physics", "coding"]
cgpa = float(input("Enter your cgpa: "))
count=0
for subject in subjects:
    count+=1
    print(f"{count}-{subject}")

if cgpa>8.5:
    print("Dean's list")
else:
    print("Keep grinding")

# %% [markdown]
# * Task 3 — Stretch Challenge (20 mins)
#
# Write a function called calculator

# %% [markdown]
# >Previous codes

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
op = input("Enter operation: ")
def calculator(x, y, op):
    try:
        return eval(f"{x}{op}{y}")
    except ZeroDivisionError:
        return("cannot divide by zero")
calculator(num1,num2,op)

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
op = input("Enter operation: ")
def calculator(x, y, op):
    if op == "+":
        return x + y
    elif op == "-":
        return x - y
    elif op == "*":
        return x * y
    elif op == "/":
        if y == 0:
            return "Cannot divide by zero"
        return x / y
    else:
        return "Invalid operator"
    try:
        return (f"{x}{op}{y}")
    except ZeroDivisionError:
        return("cannot divide by zero")
print(calculator(num1,num2,op))

# %% [markdown]
# >eval() is considered dangerous in real code because it executes any string as code.
#
# >If someone types __import__('os').system('rm -rf /') as input — you just broke a system.
#
# * The **old try/except block** at the bottom. See the problem? Once a function **hits a return**, it exits immediately. Everything after that **else: return** is dead code — it will never execute. Python won't even throw an error, it'll just silently ignore it.

# %% [markdown]
# >Correct code

# %%
def calculator(x, y, op):
    if op == "+":
        return x + y
    elif op == "-":
        return x - y
    elif op == "*":
        return x * y
    elif op == "/":
        if y == 0:
            return "Cannot divide by zero"
        return x / y
    else:
        return "Invalid operator"

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
op = input("Enter operator (+, -, *, /): ")

print(calculator(num1, num2, op))
# Out:
# 384

# %% [markdown]
# In Python, you must define a function before you call it. Your version worked because the inputs run first and the function is defined before print(calculator(...)) — but the clean habit is: define functions at the top, run logic at the bottom.
